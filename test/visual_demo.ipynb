# %%
from turb.channel_plot import *
from pyutils.plot_utils import *
from matplotlib import cm, colors
import matplotlib.pyplot as plt
import numpy as np

# %%
font_args = {'font_size' :14, }

# %% [markdown]
# # Plots related to channel flow Post-processing
#
# ## Cross Section contours
# Function `contour_channel` plot the cross-sections in xy, xz and yz surfaces at the maximum value given data.

# %%
xx = np.linspace(0, 2*np.pi, 100)
x, y, z = np.meshgrid(xx, xx, xx)
data = np.sin(x)*np.sin(y)*np.sin(z)

domain = (2*np.pi, np.pi, 1)
dims = (100, 100, 100)

fig, ax = contour_channel(domain, dims, data)
# Out:
# /Users/user/Documents/Projects/python_util/.venv/lib/python3.9/site-packages/python_utils-0.1.0-py3.9.egg/turb/channel_plot.py:70: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# # pyutils.plot_utils
#
#
# ## Contour
#
# Contour given axes and data.

# %%
y = x = np.linspace(0, 2*np.pi, 128)

data = np.sin(x)[:, np.newaxis]*np.sin(y)[np.newaxis, :]

kwargs = font_args

# %%
fig, ax = contour_single(x, y, data, levs=61, eshrink=5/6)
